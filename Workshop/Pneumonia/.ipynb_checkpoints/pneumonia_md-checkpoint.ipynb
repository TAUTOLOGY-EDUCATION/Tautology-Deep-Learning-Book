# %%
import pickle
from glob import glob

import numpy as np
import pandas as pd
from PIL import Image

# %%
saved_model = pickle.load(open("pneumonia_model.pickle", "rb"))

# %%
clf = saved_model[0]
scaler = saved_model[1]

# %%
img_path = glob("dataset/Pneumonia/*")[0]
incoming_data = Image.open(img_path)

incoming_data
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1152x760 at 0x22E96B73580>

# %%
incoming_data = incoming_data.resize([64, 64])
incoming_data = np.array(incoming_data).reshape(1, -1)
incoming_data = scaler.transform(incoming_data)

incoming_data
# Out:
# array([[0.09411765, 0.1372549 , 0.18039216, ..., 0.05098039, 0.05882353,
#         0.05882353]])

# %% [markdown]
# # Prediction

# %%
predicted_target = clf.predict(incoming_data)

# %%
predicted_target
# Out:
# array(['Pneumonia'], dtype=object)
