# %% [markdown]
# # 1. Import Libraries

# %%
import warnings

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import (
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
    r2_score,
)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

warnings.filterwarnings("ignore")

np.random.seed(12345)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %% [markdown]
# # 2. Read Data

# %%
data = pd.read_csv("set50_dataset.csv")

data
# Out:
#               Date  Open_0  STD5_Open_0  RSI14_Open_0    ATR14_0  High_0  \
# 0     Sep 06, 2011  724.53    11.294425     40.113475  15.584286  734.49
# 1     Sep 07, 2011  736.88    11.233060     44.486846  15.319694  744.25
# 2     Sep 08, 2011  740.70     7.997796     45.805181  14.922573  747.06
# 3     Sep 09, 2011  747.53     7.548580     48.174981  14.476675  748.28
# 4     Sep 12, 2011  728.89     8.215669     42.688715  14.117627  730.86
# ...            ...     ...          ...           ...        ...     ...
# 2459  Oct 01, 2021  960.35     9.114131     44.576218  12.205780  968.09
# 2460  Oct 04, 2021  968.74     5.942913     49.179916  12.151081  975.23
# 2461  Oct 05, 2021  969.26     3.800142     49.460117  12.014576  980.85
# 2462  Oct 06, 2021  980.05     6.266697     55.003979  12.042820  982.33
# 2463  Oct 07, 2021  977.83     7.068331     53.698833  11.953333  985.78
#
#        Low_0
# 0     722.61
# 1     735.60
# 2     738.38
# 3     738.83
# 4     720.25
# ...      ...
# 2459  956.65
# 2460  968.06
# 2461  968.44
# 2462  971.54
# 2463  975.52
#
# [2464 rows x 7 columns]

# %%
data.drop(["Date", "Low_0"], axis=1, inplace=True)

data
# Out:
#       Open_0  STD5_Open_0  RSI14_Open_0    ATR14_0  High_0
# 0     724.53    11.294425     40.113475  15.584286  734.49
# 1     736.88    11.233060     44.486846  15.319694  744.25
# 2     740.70     7.997796     45.805181  14.922573  747.06
# 3     747.53     7.548580     48.174981  14.476675  748.28
# 4     728.89     8.215669     42.688715  14.117627  730.86
# ...      ...          ...           ...        ...     ...
# 2459  960.35     9.114131     44.576218  12.205780  968.09
# 2460  968.74     5.942913     49.179916  12.151081  975.23
# 2461  969.26     3.800142     49.460117  12.014576  980.85
# 2462  980.05     6.266697     55.003979  12.042820  982.33
# 2463  977.83     7.068331     53.698833  11.953333  985.78
#
# [2464 rows x 5 columns]

# %% [markdown]
# # 3. Clean Data

# %% [markdown]
# ## 3.1. Handle Missing Values

# %% [markdown]
# ### 3.1.1. Check Missing Values

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2464 entries, 0 to 2463
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open_0        2464 non-null   float64
#  1   STD5_Open_0   2464 non-null   float64
#  2   RSI14_Open_0  2464 non-null   float64
#  3   ATR14_0       2464 non-null   float64
#  4   High_0        2464 non-null   float64
# dtypes: float64(5)
# memory usage: 96.4 KB

# %% [markdown]
# ### 3.1.2. Remove Missing Values (Listwise Deletion)

# %%
# no NaN to remove
# data.dropna(axis=0, inplace=True)

# %% [markdown]
# ## 3.2. Handle Outliers

# %% [markdown]
# ### 3.2.1. Check Outliers

# %%
data.describe()
# Out:
#             Open_0  STD5_Open_0  RSI14_Open_0      ATR14_0       High_0
# count  2464.000000  2464.000000   2464.000000  2464.000000  2464.000000
# mean    966.719874     7.601789     51.986774    13.016029   972.018925
# std     114.038638     5.445760     12.054915     4.724891   113.482759
# min     598.350000     0.825348      9.306245     5.275736   607.320000
# 25%     893.390000     4.320191     44.056090    10.386445   898.932500
# 50%     975.225000     6.398427     51.756332    12.044799   980.035000
# 75%    1056.692500     9.273195     60.287245    14.573723  1062.325000
# max    1212.540000    71.401463     85.597369    45.576001  1223.670000

# %% [markdown]
# ### 3.2.2. Remove Outliers

# %%
# no outlier to remove

# %% [markdown]
# # 4. Split Dataset into Training & Test Sets

# %%
target_name = "High_0"
feature_name = list(data.columns.drop(target_name))

# %%
X = data[feature_name]
y = data[target_name]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, shuffle=False)

# %% [markdown]
# # ### 5. Data Preparation

# %% [markdown]
# # 6. Model Creation

# %% [markdown]
# ## 6.1. Setting Parameters

# %%
reg = LinearRegression()

# %% [markdown]
# ## 6.2. Train Model

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 6.3. Model's Weight & Bias

# %%
reg.coef_
# Out:
# array([ 0.99999423,  0.18317603, -0.03883808,  0.17106379])

# %%
reg.intercept_
# Out:
# 3.660121303948017

# %% [markdown]
# # 7. Prediction

# %% [markdown]
# ## 7.1. Training Set

# %%
y_pred_train = reg.predict(X_train)

# %% [markdown]
# ## 7.2. Test Set

# %%
y_pred_test = reg.predict(X_test)

# %% [markdown]
# # 8. Model Evaluation

# %% [markdown]
# ## 8.1. Training Set

# %% [markdown]
# ### 8.1.1. Scoring

# %%
print("r2_score =\t\t\t", r2_score(y_train, y_pred_train))
print("mean_squared_error =\t\t", mean_squared_error(y_train, y_pred_train))
print("mean_absolute_error =\t\t", mean_absolute_error(y_train, y_pred_train))
print(
    "mean_absolute_percentage_error =",
    mean_absolute_percentage_error(y_train, y_pred_train),
)
# Out:
# r2_score =			 0.9988367792634959
# mean_squared_error =		 16.03633960030595
# mean_absolute_error =		 2.949961069193139
# mean_absolute_percentage_error = 0.0030771809846577955

# %% [markdown]
# ### 8.1.2. Scatter Plot between Predicted & Actual Values

# %%
plt.scatter(y_pred_train, y_train)

plt.plot(y_pred_train, y_pred_train, color="red")

plt.title("Scatter Plot between Predicted & Actual Values")
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(0, 0.5, 'Actual')

# %% [markdown]
# ## 8.2. Test Set

# %% [markdown]
# ### 8.2.1. Scoring

# %%
print("r2_score =\t\t\t", r2_score(y_test, y_pred_test))
print("mean_squared_error =\t\t", mean_squared_error(y_test, y_pred_test))
print("mean_absolute_error =\t\t", mean_absolute_error(y_test, y_pred_test))
print(
    "mean_absolute_percentage_error =",
    mean_absolute_percentage_error(y_test, y_pred_test),
)
# Out:
# r2_score =			 0.9942429600445835
# mean_squared_error =		 46.47570179485583
# mean_absolute_error =		 3.8981822347287287
# mean_absolute_percentage_error = 0.004298454455850625

# %% [markdown]
# ### 8.2.2. Scatter Plot between Predicted & Actual Values

# %%
plt.scatter(y_pred_test, y_test)

plt.plot(y_pred_test, y_pred_test, color="red")

plt.title("Scatter Plot between Predicted & Actual Values")
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(0, 0.5, 'Actual')

# %% [markdown]
# ### 8.2.3. Plot between Predicted & Actual Values (Zoom)

# %%
y_test = y_test.to_numpy()

# %%
step = 10

import math

n_rows = int(math.ceil(len(y_test) / (2 * step)))

fig = plt.figure(figsize=(18, 6 * n_rows))

for i in range(0, len(y_test), step):
    start = i
    stop = min(i + step, len(y_test))
    plt.subplot(n_rows, 2, i // step + 1)
    plt.plot(y_test[start:stop], label=f"Actual High {start}-{stop-1}")
    plt.plot(y_pred_test[start:stop], "*", label=f"Predicted High {start}-{stop-1}")
    plt.legend()

# %% [markdown]
# # 9. Save Model

# %%
import pickle

# %%
pickle.dump((reg, feature_name), open("set50_model.pickle", "wb"))
