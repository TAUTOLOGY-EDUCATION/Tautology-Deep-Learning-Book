# %%
import pickle
from glob import glob

import cv2
import numpy as np
import pandas as pd
from PIL import Image

# %%
saved_model = pickle.load(open("alzheimer_model.pickle", "rb"))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
clf = saved_model[0]
scaler = saved_model[1]

# %%
img_path = glob("dataset/MildDemented/*")[1]
incoming_data = Image.open(img_path)

incoming_data
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=176x208 at 0x1D2461CD670>

# %%
incoming_data = incoming_data.resize([64, 64])
incoming_data = np.array(incoming_data)

incoming_data = incoming_data.reshape(1, -1)
incoming_data_scaled = scaler.transform(incoming_data)

incoming_data_scaled
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Prediction

# %%
predicted_target = clf.predict(incoming_data_scaled)

# %%
predicted_target
# Out:
# array(['alzheimer'], dtype='<U13')
